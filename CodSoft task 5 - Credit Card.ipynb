# %%
import re
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, precision_score, recall_score, accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.datasets import fetch_openml
mpl.rcParams['figure.figsize'] = [16,9]
from sklearn.ensemble import GradientBoostingClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv('creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
for i in df.columns:
    print(len(df[i].unique()))
# Out:
# 124592
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 275663
# 32767
# 2

# %%
df['Class'].unique()
# Out:
# array([0, 1])

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
for i in df.select_dtypes(exclude='object').columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(data = df, x=i)
    plt.show()

# %%
plt.figure(figsize=(27,17))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
min_max_scaler = RobustScaler()
df_scaler = min_max_scaler.fit_transform(df)
df_scaler = pd.DataFrame(df_scaler, columns = df.columns)

# %%
df_scaler
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0      -0.994983 -0.616237 -0.098602  1.228905  0.878152 -0.217859  0.631245
# 1      -0.994983  0.524929  0.143100 -0.006970  0.293974  0.087726  0.164395
# 2      -0.994972 -0.615587 -1.002407  0.830932  0.251024 -0.344345  1.778007
# 3      -0.994972 -0.440239 -0.178789  0.841250 -0.529808  0.033775  1.303832
# 4      -0.994960 -0.526089  0.579239  0.713861  0.265632 -0.270695  0.317183
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.034951 -5.321622  7.135767 -5.222589 -1.285699 -4.073679 -1.999082
# 284803  1.034963 -0.335820 -0.085979  0.967471 -0.451476  0.707747  1.142041
# 284804  1.034975  0.850377 -0.261532 -1.788463 -0.337932  2.059687  2.832770
# 284805  1.034975 -0.115629  0.331602  0.272567  0.445763 -0.248270  0.769496
# 284806  1.035022 -0.246654 -0.182004  0.272998 -0.305547  0.032059 -0.321743
#
# ...

# %%
X = df_scaler.drop('Class', axis=1)
y = df_scaler['Class']

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)
print(y_resampled.value_counts())
# Out:
# Class
# 0.0    284315
# 1.0    284315
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)

# %%
scaler = RobustScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
ran_for = RandomForestClassifier(n_estimators=500, min_samples_split=5, max_samples=0.8,n_jobs=-1,random_state=42)

# %%
ran_for.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_samples=0.8, min_samples_split=5, n_estimators=500,
#                        n_jobs=-1, random_state=42)

# %%
prediction1 = ran_for.predict(X_test)

# %%
accuracy_score(prediction1, y_test)
# Out:
# 0.9998593109755025

# %%
precision_score(prediction1, y_test)
# Out:
# 1.0

# %%
recall_score(prediction1, y_test)
# Out:
# 0.9997187011023401

# %%
f1_score(prediction1, y_test)
# Out:
# 0.9998593307661198

# %%
confusion_matrix(y_test, prediction1)
# Out:
# array([[56847,    16],
#        [    0, 56863]])

# %%
plt.figure(figsize=(6,4))
plt.title("Confusion Matrix for Random Forest")
sns.heatmap(confusion_matrix(y_test, prediction1),annot=True, cmap = 'viridis')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
prediction2 = log_reg.predict(X_test)

# %%
accuracy_score(prediction2, y_test)
# Out:
# 0.948446265585706

# %%
precision_score(prediction2, y_test)
# Out:
# 0.9213724214339729

# %%
recall_score(prediction2, y_test)
# Out:
# 0.9741186970102633

# %%
f1_score(prediction2, y_test)
# Out:
# 0.9470116677361339

# %%
confusion_matrix(y_test, prediction2)
# Out:
# array([[55471,  1392],
#        [ 4471, 52392]])

# %%
plt.figure(figsize=(6,4))
plt.title("Confusion Matrix for Logistic Regression")
sns.heatmap(confusion_matrix(y_test, prediction2),annot=True, cmap = 'viridis')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Amount'], bins=50, kde=True)
plt.title('Amount Distribution')
plt.show()
